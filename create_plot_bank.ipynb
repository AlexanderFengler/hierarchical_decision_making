# %% [markdown]
# # Import Packages and Functions

# %%
import hddm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from helper_functions import *

# %% [markdown]
# # Load observed and model data

# %%
observed_data = pd.read_csv('data/chong_data_hddm_ready.csv', index_col = 0)

# %%
trade_off = pd.read_pickle("mic2_adj_all_true_p_0")
parallel = pd.read_pickle("par2_all_true_p_0")
sequential = pd.read_pickle("seq2_all_true_p_0")

# %% [markdown]
# # Create plot bank

# %%
plt.figure(figsize=(27,17))
all_plots(observed_data)
plt.suptitle('Observed Data Plot Bank', fontsize=24)
# Out:
# Text(0.5, 0.98, 'Observed Data Plot Bank')
